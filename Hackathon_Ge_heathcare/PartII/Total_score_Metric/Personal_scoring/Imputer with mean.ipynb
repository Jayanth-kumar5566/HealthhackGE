# %%
import pandas
import numpy
from sklearn.preprocessing import Imputer

# %%
df=pandas.read_csv("data.csv")

# %%
df
# Out:
#         NP1COG   NP1HALL   NP1DPRS   NP1ANXS   NP1APAT    NP1DDS   NP2SPCH  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     1.000000  0.000000  1.000000  0.000000  1.000000  0.000000  1.000000
# 2     0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  1.000000  0.000000  0.000000  0.000000  1.000000
# 4     0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  1.000000
# 5     1.000000  0.000000  0.000000  0.000000  1.000000  0.000000  1.000000
# 6     1.000000  0.000000  0.000000  1.000000  2.000000  0.000000  1.000000
# 7     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8     1.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000
# 9     1.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
# 10    1.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
fill_0=Imputer(missing_values="NaN",strategy="mean",axis=0)
df1=fill_0.fit_transform(df)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1)
# Out:
# numpy.ndarray

# %%
df1
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.61000000e+02,   2.11000000e+02,   3.52423000e+01],
#        [  1.00000000e+00,   0.00000000e+00,   1.00000000e+00, ...,
#           1.17244094e+02,   1.26200000e+02,   3.52423000e+01],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.17244094e+02,   1.42800000e+02,   3.52423000e+01],
#        ...,
#        [  9.97571000e-01,   0.00000000e+00,   3.97826000e-01, ...,
#           1.17244094e+02,   1.35976846e+02,   3.52423000e+01],
#        [  6.22752000e-01,   0.00000000e+00,   1.15308000e-01, ...,
#           1.17244094e+02,   1.35976846e+02,   3.52423000e+01],
#        [  8.74995000e-01,   0.00000000e+00,   0.00000000e+00, ...,
#           1.17244094e+02,   1.35976846e+02,   3.52423000e+01]])

# %%
df1.shape
# Out:
# (1345, 69)

# %%
df.shape
# Out:
# (1345, 69)

# %%
import numpy
numpy.savetxt('tocopypaste.csv',df1,delimiter=',')

# %%
df1.to_csv("data.csv")
# Out:
# -------------------------------------------------------------------------
# AttributeError                          Traceback (most recent call last)
# <ipython-input-19-4c6791508299> in <module>()
# ----> 1 df1.to_csv("data.csv")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'
